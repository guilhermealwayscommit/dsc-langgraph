# %% [markdown]
# # [Langsmith](https://python.langchain.com/v0.1/docs/langsmith/walkthrough/) + [Langgraph](https://langchain-ai.github.io/langgraph/#example) + [langchain_neospace](https://github.com/neospace-ai/langchain-neospace/releases)

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Installation

# %%
# %pip install -U langgraph langsmith
# %pip install langchain-openai
# %pip install python-dotenv
# %pip install --upgrade --quiet  langchain langchainhub
# %pip install --upgrade --quiet  tiktoken pandas duckduckgo-search
# %pip install langchain_community
# %pip install https://github.com/neospace-ai/langchain-neospace/releases/download/v1.0.0-TuSpX3J7/langchain_neospace-0.1.18-py3-none-any.whl
# Out:
# Requirement already satisfied: langgraph in ./.venv/lib/python3.12/site-packages (0.1.17)
# Requirement already satisfied: langsmith in ./.venv/lib/python3.12/site-packages (0.1.94)
# Requirement already satisfied: langchain-core<0.3,>=0.2.22 in ./.venv/lib/python3.12/site-packages (from langgraph) (0.2.25)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith) (3.10.6)
# Requirement already satisfied: pydantic<3,>=1 in ./.venv/lib/python3.12/site-packages (from langsmith) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.12/site-packages (from langsmith) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.22->langgraph) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.22->langgraph) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.22->langgraph) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3,>=0.2.22->langgraph) (8.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langsmith) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langsmith) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langsmith) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith) (2024.7.4)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.22->langgraph) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-openai in ./.venv/lib/python3.12/site-packages (0.1.19)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.24 in ./.venv/lib/python3.12/site-packages (from langchain-openai) (0.2.25)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in ./.venv/lib/python3.12/site-packages (from langchain-openai) (1.37.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./.venv/lib/python3.12/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (0.1.94)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.24->langchain-openai) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.32.0->langchain-openai) (4.12.2)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain-openai) (3.7)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.24->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.24->langchain-openai) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.24->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.24->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.12/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_community in ./.venv/lib/python3.12/site-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.12/site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./.venv/lib/python3.12/site-packages (from langchain_community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./.venv/lib/python3.12/site-packages (from langchain_community) (3.10.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./.venv/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.9 in ./.venv/lib/python3.12/site-packages (from langchain_community) (0.2.11)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in ./.venv/lib/python3.12/site-packages (from langchain_community) (0.2.25)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in ./.venv/lib/python3.12/site-packages (from langchain_community) (0.1.94)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in ./.venv/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.12/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in ./.venv/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.9->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in ./.venv/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.9->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.23->langchain_community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in ./.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.9->langchain_community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-neospace==0.1.18
#   Downloading https://github.com/neospace-ai/langchain-neospace/releases/download/v1.0.0-TuSpX3J7/langchain_neospace-0.1.18-py3-none-any.whl (29 kB)
# Collecting neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl (from langchain-neospace==0.1.18)
#   Using cached https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl (339 kB)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.20 in ./.venv/lib/python3.12/site-packages (from langchain-neospace==0.1.18) (0.2.25)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./.venv/lib/python3.12/site-packages (from langchain-neospace==0.1.18) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (0.1.94)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (8.5.0)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-neospace==0.1.18) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-neospace==0.1.18) (2.32.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (0.27.0)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./.venv/lib/python3.12/site-packages (from neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (4.12.2)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (3.7)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->neospace@ https://github.com/neospace-ai/neospace-python/releases/download/v1.0.0-unXEA9WF/neospace-1.37.0-py3-none-any.whl->langchain-neospace==0.1.18) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./.venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./.venv/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.20->langchain-neospace==0.1.18) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-neospace==0.1.18) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-neospace==0.1.18) (2.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Env

# %%
from dotenv import load_dotenv, find_dotenv
import os
dotenv = find_dotenv()
print(f"Found .env file at {dotenv}")
load_dotenv(dotenv_path=dotenv, override=True)

from uuid import uuid4

unique_id = uuid4().hex[0:8]
os.environ["LANGCHAIN_PROJECT"] = f"Tracing Walkthrough - {unique_id}"
# Out:
# Found .env file at /home/guilherme-alves-carvalho/Documents/repos/dsc-langgraph/.env

# %% [markdown]
# ### Helpers

# %%
import json
import datetime
from langchain_core.messages import BaseMessage, HumanMessage

class LLMLogger:
    def __init__(self, wrapped_class):
        self.wrapped_class = wrapped_class
        run_date = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        os.makedirs(f"logs/{run_date}", exist_ok=True)

        self.req_res_f = f"logs/{run_date}/exec.json"

        self.req_res = []

    def __del__(self):
        self.write_to_file()

    def write_to_file(self):
        with open(self.req_res_f, "w+") as f:
            json.dump(self.req_res, f, indent=4, ensure_ascii=False)
        

    def __getattr__(self, attr):
        original_func = getattr(self.wrapped_class, attr)

        def wrapper(*args, **kwargs):

            result = original_func(*args, **kwargs)

            self.req_res.append({"request": kwargs, "response": result.model_dump()})
            return result

        return wrapper
    
def show_message(message: BaseMessage):
    if message.type == "assistant" and message.function_call:
        print(f"{message.type} function call => {message.function_call}")

    print(f"{message.type} => {message.content}")

# %% [markdown]
# ## Workflow

# %% [markdown]
# ### Build

# %%
from typing import Annotated, Literal

from langchain_core.messages import SystemMessage

from langgraph.checkpoint import MemorySaver
from langgraph.graph import END, StateGraph, MessagesState
from langgraph.prebuilt import ToolNode

import os

from langchain import hub
from langchain_community.tools import DuckDuckGoSearchResults
from langchain_neospace import ChatNeoSpace

# Import things that are needed generically
from langchain.pydantic_v1 import BaseModel, Field
from langchain.tools import BaseTool, StructuredTool, tool
# https://smith.langchain.com/hub/wfh/langsmith-agent-prompt?organizationId=3e9f24f6-5a49-5652-a085-d776844de3bf
# Fetches the latest version of this prompt
prompt = hub.pull("wfh/langsmith-agent-prompt:5d466cbc")

@tool
def executar_pix(query: str) :
    """Executar pix"""
    return {"status": 500}


# Define the tools for the agent to use
tools = [
    DuckDuckGoSearchResults(
        name="duck_duck_go"
        # type="DEFAULT"      
    ),  # General internet search using DuckDuckGo
    # executar_pix
]
# implement an user tool

tool_node = ToolNode(tools)

extra_body = {"session_id": "ERHJWKRHWQE"}

model = ChatNeoSpace(
    model="/cortex/checkpoints/cortex-7b-instruct-0.0.1",
    temperature=0,
    extra_body=extra_body,
)

model.client = LLMLogger(model.client)

model = model.bind_tools(tools, extra_body=extra_body)

class State(MessagesState):
    extra_body: Annotated[dict, "The configuration for the workflow"] # validation needs

# Define the function that determines whether to continue or not
def should_continue(state: State) -> Literal["tools", "agent", END]:
    messages = state['messages']
    last_message = messages[-1]

    # If the LLM makes a tool call, then we route to the "tools" node
    if last_message.tool_calls:
        return "tools"

    # Otherwise, we stop (reply to the user)
    return END


# Define the function that calls the model
def call_model(state: State):
    messages = state['messages']
  
    response = model.bind(extra_body=state["extra_body"]).invoke(messages)
    # We return a list, because this will get added to the existing list

    return {"messages": [response]}


# Define a new graph
workflow = StateGraph(State)

# Define the two nodes we will cycle between
workflow.add_node("agent", call_model)
workflow.add_node("tools", tool_node)

# Set the entrypoint as `agent`
# This means that this node is the first one called
workflow.set_entry_point("agent")

# We now add a conditional edge
workflow.add_conditional_edges(
    # First, we define the start node. We use `agent`.
    # This means these are the edges taken after the `agent` node is called.
    "agent",
    # Next, we pass in the function that will determine which node is called next.
    should_continue,
)

# We now add a normal edge from `tools` to `agent`.
# This means that after `tools` is called, `agent` node is called next.
workflow.add_edge("tools", 'agent')

# Initialize memory to persist state between graph runs
checkpointer = MemorySaver()

# Finally, we compile it!
# This compiles it into a LangChain Runnable,
# meaning you can use it as you would any other runnable.
# Note that we're (optionally) passing the memory when compiling the graph
app = workflow.compile(checkpointer=checkpointer)

# %% [markdown]
# ### Run

# %%
from langchain_core.tracers.context import tracing_v2_enabled

from langsmith import Client
langsmith_client = Client(api_url=os.getenv("MERCURY_ENDPOINT"))
with tracing_v2_enabled(client=langsmith_client):
    extra_body["customer"] = {
        "id": "45646",
        "name": "Felipe Silva",
        "gender": "male"
    }

    state = {"messages": [SystemMessage(content="Você é um agente especialista financeiro, mostre todos os seus cálculos realizados em sua resposta")], "extra_body": extra_body}
    show_message(state["messages"][-1])

    question = HumanMessage(content=input())
    state["messages"] += [question]

    show_message(state["messages"][-1])


    while state["messages"][-1].content != "q":
        state = app.invoke(
            state,
            config={"thread_id": 42, "workflow": workflow},
        )

        show_message(state["messages"][-1])

        question = HumanMessage(content=input())
        state["messages"] += [question]
        show_message(state["messages"][-1])

        
    model.client.write_to_file()
# Out:
# system => Você é um agente especialista financeiro, mostre todos os seus cálculos realizados em sua resposta
# human => Oi
# ai =>  [{"name": "duck_duck_go", "arguments": {"query": "financial calculations excel formulas"}}]
#
# Aqui estão alguns dos melhores recursos de cálculos financeiros disponíveis no Excel:
#
# 1. Função SUM: Somar valores em uma célula ou um conjunto de células.
#    Fórmula: `=SUM(A1:A10)`
#
# 2. Função COUNT: Contar a quantidade de valores numa célula ou um conjunto de células.
#    Fórmula: `=COUNT(B1:B10)`
#
# 3. Função AVERAGE: Calcular a média dos valores numa célula ou um conjunto de células.
#    Fórmula: `=AVERAGE(C1:C10)`
#
# 4. Função MAX e MIN: Encontrar o maior e o menor valor numa célula ou um conjunto de células.
#    Fórmula: `=MAX(D1:D10)` ou `=MIN(D1:D10)`
#
# 5. Função IF: Executar uma ação condicional.
#    Fórmula: `=IF(E1>100,"Acima do valor", "Abaixo do valor")`
#
# 6. Função VLOOKUP: Localizar um valor em uma coluna e retornar um valor em uma célula relacionada.
#    Fórmula: `=VLOOKUP(F1, G1:H10, 2, FALSE)`
#
# 7. Função INDEX e MATCH: Localizar um valor em uma célula e retornar um valor em outra célula relacionada.
#    Fórmula: `=INDEX(I1:I10, MATCH(J1, K1:K10, 0))`
#
# 8. Função PMT: Calcular o pagamento mensal de um empréstimo.
#    Fórmula: `=PMT(interest_rate, number_of_payments, loan_amount, [zero_or_present_value])`
#
# 9. Função NPV: Calcular o valor presente de um fluxo de caixa futuro.
#    Fórmula: `=NPV(rate, value_if_financed)`
#
# 10. Função IRR: Calcular a taxa de retorno interna de um projeto.
#     Fórmula: `=IRR(cash_flow_values, guess)`
# human => q
